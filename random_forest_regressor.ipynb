# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

dataset=pd.read_csv("/content/drive/My Drive/Crime_Data_from_2010_to_2019.csv")
#dataset.drop(['DATE OCC','AREA NAME','Crm Cd Desc','Vict Sex','LAT','LON','DR_NO','Vict Age','Vict Descent','Part 1-2','Crm Cd 1','Crm Cd 2','Crm Cd 3','Crm Cd 4','Date Rptd','TIME OCC','Rpt Dist No','Mocodes','Premis Cd','Premis Desc','Weapon Used Cd','Weapon Desc','Status', 'Status Desc','LOCATION','Cross Street'],axis = 1, inplace = True)
dataset
# Out:
#              DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010 12:00:00 AM      1350
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010 12:00:00 AM        45
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010 12:00:00 AM      1515
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010 12:00:00 AM       150
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010 12:00:00 AM      2100
# ...            ...                     ...                     ...       ...
# 2117584  190608903  03/28/2019 12:00:00 AM  03/28/2019 12:00:00 AM       400
# 2117585  190715222  08/15/2019 12:00:00 AM  08/14/2019 12:00:00 AM      1810
# 2117586  192004409  01/06/2019 12:00:00 AM  01/06/2019 12:00:00 AM      2100
# 2117587  191716777  10/17/2019 12:00:00 AM  10/16/2019 12:00:00 AM      1800
# 2117588  190805435  02/01/2019 12:00:00 AM  02/01/2019 12:00:00 AM      1615
#
# ...

# %%
dataset.columns
# Out:
# Index(['DR_NO', 'Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA ', 'AREA NAME',
#        'Rpt Dist No', 'Part 1-2', 'Crm Cd', 'Crm Cd Desc', 'Mocodes',
#        'Vict Age', 'Vict Sex', 'Vict Descent', 'Premis Cd', 'Premis Desc',
#        'Weapon Used Cd', 'Weapon Desc', 'Status', 'Status Desc', 'Crm Cd 1',
#        'Crm Cd 2', 'Crm Cd 3', 'Crm Cd 4', 'LOCATION', 'Cross Street', 'LAT',
#        'LON'],
#       dtype='object')

# %%
#dataset['DATE OCC'] = pd.to_datetime(dataset['DATE OCC'])
dataset['DATE OCC']=dataset['DATE OCC'].str[0:10]
dataset['DATE OCC']
# Out:
# 0          02/20/2010
# 1          09/12/2010
# 2          08/09/2010
# 3          01/05/2010
# 4          01/02/2010
#               ...
# 2117584    03/28/2019
# 2117585    08/14/2019
# 2117586    01/06/2019
# 2117587    10/16/2019
# 2117588    02/01/2019
# Name: DATE OCC, Length: 2117589, dtype: object

# %%
dataset[["day", "month", "year"]] = dataset["DATE OCC"].str.split("/", expand = True)

# %%
dataset
# Out:
#              DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA   \
# 0          1307355  02/20/2010 12:00:00 AM  02/20/2010      1350     13
# 1         11401303  09/13/2010 12:00:00 AM  09/12/2010        45     14
# 2         70309629  08/09/2010 12:00:00 AM  08/09/2010      1515     13
# 3         90631215  01/05/2010 12:00:00 AM  01/05/2010       150      6
# 4        100100501  01/03/2010 12:00:00 AM  01/02/2010      2100      1
# ...            ...                     ...         ...       ...    ...
# 2117584  190608903  03/28/2019 12:00:00 AM  03/28/2019       400      6
# 2117585  190715222  08/15/2019 12:00:00 AM  08/14/2019      1810      7
# 2117586  192004409  01/06/2019 12:00:00 AM  01/06/2019      2100     20
# 2117587  191716777  10/17/2019 12:00:00 AM  10/16/2019      1800     17
# 2117588  190805435  02/01/2019 12:00:00 AM  02/01/2019      1615      8
#
#           AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# ...

# %%
dataset['Crm Cd']
# Out:
# 0          900
# 1          740
# 2          946
# 3          900
# 4          122
#           ...
# 2117584    648
# 2117585    331
# 2117586    930
# 2117587    420
# 2117588    330
# Name: Crm Cd, Length: 2117589, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X=dataset[['day','month','year','Crm Cd','Vict Age']]
y=dataset[['LAT','LON']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.01)

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestRegressor

#Create a Gaussian Classifier
clf=RandomForestRegressor(n_estimators=10)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("\nRMSE: ", rmse)
# Out:
# RMSE:  1.473

# %%
from sklearn.metrics import mean_absolute_error
error_MAE = float(format(np.sqrt(mean_absolute_error(y_test, y_pred)), '.3f'))
print(' Test MAE : %3f' %error_MAE)
# Out:
#  Test MAE : 0.372000

# %%
test_data=y_test[['LAT','LON']]
test_data.reset_index()
# Out:
#          index      LAT       LON
# 0      2061071  34.2440 -118.5583
# 1      1423299  34.2434 -118.4218
# 2       947800  33.9397 -118.2481
# 3      1326597  34.0531 -118.2671
# 4       696142  34.2085 -118.4698
# ...        ...      ...       ...
# 21171   743025  33.9310 -118.2532
# 21172  1026611  34.0073 -118.2969
# 21173   539144  34.1903 -118.4257
# 21174  1022447  33.9618 -118.3068
# 21175   403252  33.7740 -118.2659
#
# [21176 rows x 3 columns]

# %%
y_test.reset_index()
# Out:
#          index      LAT       LON
# 0      2061071  34.2440 -118.5583
# 1      1423299  34.2434 -118.4218
# 2       947800  33.9397 -118.2481
# 3      1326597  34.0531 -118.2671
# 4       696142  34.2085 -118.4698
# ...        ...      ...       ...
# 21171   743025  33.9310 -118.2532
# 21172  1026611  34.0073 -118.2969
# 21173   539144  34.1903 -118.4257
# 21174  1022447  33.9618 -118.3068
# 21175   403252  33.7740 -118.2659
#
# [21176 rows x 3 columns]

# %%
y_pred
# Out:
# array([[  34.20319955, -118.42403077],
#        [  34.259875  , -118.451961  ],
#        [  34.06948   , -118.33356   ],
#        ...,
#        [  34.103301  , -118.382557  ],
#        [  34.00824   , -118.369975  ],
#        [  34.048965  , -118.3374425 ]])

# %%
len(y_pred)
# Out:
# 21176

# %%
predictions=pd.DataFrame(data=y_pred,columns=['pred_LAT','pred_LON'])
predictions_df=pd.merge(y_test,predictions,left_index=True, right_index=True)
predictions_df.reset_index()
# Out:
#      index      LAT       LON   pred_LAT    pred_LON
# 0    15764  34.0326 -118.3470  34.035833 -118.327760
# 1     1606  34.0442 -118.2439  34.103600 -118.352004
# 2     7436  34.0707 -118.2795  33.991860 -118.374320
# 3     2080  34.0484 -118.2338  34.112367 -118.420153
# 4     8134  34.0433 -118.2829  34.051303 -118.286860
# ..     ...      ...       ...        ...         ...
# 202  17618  34.0370 -118.2777  34.117060 -118.393130
# 203   9594  34.0481 -118.2779  34.051052 -118.309564
# 204   1891  34.0375 -118.2700  34.030173 -118.365530
# 205   8329  34.0582 -118.2805  33.955321 -118.370663
# 206  20821  34.0328 -118.2964  34.080575 -118.379686
#
# [207 rows x 5 columns]

# %%
dataset.iloc[[289616]]
# Out:
#             DR_NO               Date Rptd    DATE OCC  TIME OCC  AREA   \
# 289616  110809412  05/03/2011 12:00:00 AM  04/15/2011      1230      8
#
#        AREA NAME  Rpt Dist No  Part 1-2  Crm Cd Crm Cd Desc  ... Crm Cd 2  \
# 289616   West LA          899         1     648       ARSON  ...    648.0
#
#         Crm Cd 3 Crm Cd 4                                 LOCATION  \
# 289616       NaN      NaN  8800    VENICE                       BL
#
#         Cross Street      LAT       LON day month  year
# 289616           NaN  34.0311 -118.3851  04    15  2011
#
# [1 rows x 31 columns]

# %%
import folium
m = folium.Map(location=[predictions_df.pred_LAT.mean(), predictions_df.pred_LON.mean()], zoom_start=14)
for index, row in predictions_df.iterrows():
    folium.CircleMarker([row['pred_LAT'], row['pred_LON']],
                        radius=3,
                        fill_color="#3db7e4", # divvy color
                       ).add_to(m)
m.save('mymap.html')

# %%
m.save('mymap.html')

# %%
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import webbrowser
webbrowser.open('mymap.html')
# Out:
# False

# %%
from google.colab import files
files.download('mymap.html')

# %%
m = folium.Map(location=[predictions_df.LAT.mean(), predictions_df.LON.mean()], zoom_start=14)
for index, row in predictions_df.iterrows():
    folium.CircleMarker([row['LAT'], row['LON']],
                        radius=3,
                        fill_color="#3db7e4", # divvy color
                       ).add_to(m)
m.save('test.html')

# %%
from google.colab import files
files.download('test.html')

# %%
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
